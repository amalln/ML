# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('HR_comma_sep.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
tr_data=data[['satisfaction_level','average_montly_hours','promotion_last_5years','salary','Department']]

# %%
tr_data
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary Department
# 0         low      sales
# 1      medium      sales
# 2      medium      sales
# ...

# %%
tr_data.drop('Department',axis='columns',inplace=True)
# Out:
# C:\Users\91999\AppData\Local\Temp\ipykernel_8140\2737757235.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr_data.drop('Department',axis='columns',inplace=True)

# %%
tr_data
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummy=pd.get_dummies(tr_data[['salary']],prefix='salary')
dummy
# Out:
#        salary_high  salary_low  salary_medium
# 0            False        True          False
# 1            False       False           True
# 2            False       False           True
# 3            False        True          False
# 4            False        True          False
# ...            ...         ...            ...
# 14994        False        True          False
# 14995        False        True          False
# 14996        False        True          False
# 14997        False        True          False
# 14998        False        True          False
#
# [14999 rows x 3 columns]

# %%
dummy['salary_high']=dummy['salary_high'].replace(True,1)
dummy['salary_high']=dummy['salary_high'].replace(False,0)
dummy['salary_low']=dummy['salary_low'].replace(True,1)
dummy['salary_low']=dummy['salary_low'].replace(False,0)
dummy['salary_medium']=dummy['salary_medium'].replace(False,0)
dummy['salary_medium']=dummy['salary_medium'].replace(True,1)
dummy
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
tr_data2=pd.concat([tr_data,dummy],axis='columns')
tr_data2
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low            0           1              0
# ...

# %%
tr_data2.drop('salary',axis='columns',inplace=True)
tr_data2
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
